# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import altair as alt

# %%
file_path = "C:/Users/Andre/Documents/GitHub/project-repository-team_iowa/train.csv"
data = pd.read_csv(file_path)

data
# Out:
#        review_id                        title    year  \
# 0              1  Spooky's Jump Scare Mansion  2016.0
# 1              2  Spooky's Jump Scare Mansion  2016.0
# 2              3  Spooky's Jump Scare Mansion  2016.0
# 3              4  Spooky's Jump Scare Mansion  2015.0
# 4              5  Spooky's Jump Scare Mansion  2015.0
# ...          ...                          ...     ...
# 17489      25535                 EverQuest II  2012.0
# 17490      25536                 EverQuest II  2017.0
# 17491      25537                 EverQuest II  2011.0
# 17492      25538                 EverQuest II     NaN
# 17493      25539                 EverQuest II     NaN
#
#                                              user_review  user_suggestion
# 0      I'm scared and hearing creepy voices.  So I'll...                1
# 1      Best game, more better than Sam Pepper's YouTu...                1
# 2      A littly iffy on the controls, but once you kn...                1
# ...

# %%
def process_data(data, content):
    
    '''
    data is in a csv format
    
    content is the column in data set that you want to process
    
    Content_Parsed_4 is the final processed output 
    
    '''
    
    #\r and \n
    data['Content_Parsed_1'] = content.str.replace("\r", " ")
    data['Content_Parsed_1'] = data['Content_Parsed_1'].str.replace("\n", " ")
    data['Content_Parsed_1'] = data['Content_Parsed_1'].str.replace("    ", " ")

    # quotation marks
    data['Content_Parsed_1'] = data['Content_Parsed_1'].str.replace('"', '')

    # Lower casing all words so that upper case words (ex: at the begineeing of a sentence) 
    # are read the same as lower case words
    data['Content_Parsed_2'] = data['Content_Parsed_1'].str.lower()

    # punctuation signs
    punctuation_signs = list("?:!.,;")
    data['Content_Parsed_3'] = data['Content_Parsed_2']

    for i in punctuation_signs:
        data['Content_Parsed_3'] = data['Content_Parsed_3'].str.replace(i, '')
    
    # Possesvive pronouns 
    data['Content_Parsed_4'] = data['Content_Parsed_3'].str.replace("'s", "")
    
    ltk.download('punkt')
    nltk.download('wordnet')

    #lemmatizer
    wordnet_lemmatizer = WordNetLemmatizer()

    nrows = len(data)
    lemmatized_text_list = []

    for i in range(0, nrows):
    
        lemmatized_list = []
    
        text = data.loc[i]['Content_Parsed_4']
        text_words = text.split(" ")

    for word in text_words:
        lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))
        
    lemmatized_text = " ".join(lemmatized_list)
    
    lemmatized_text_list.append(lemmatized_text)

    data['Content_Parsed_5'] = lemmatized_text_list
    
    #stopwords
    regex = r"\b" + word + r"\b"

    data['Content_Parsed_6'] = data['Content_Parsed_5']

    for stop_word in stop_words:

        regex_stopword = r"\b" + stop_word + r"\b"
        data['Content_Parsed_6'] = data['Content_Parsed_6'].str.replace(regex_stopword, '')
    
    return data
    
processed = process_data(data, data['user_review'])

processed
# Out:
# <ipython-input-8-e6db41786021>:27: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['Content_Parsed_3'] = data['Content_Parsed_3'].str.replace(i, '')
#        review_id                        title    year  \
# 0              1  Spooky's Jump Scare Mansion  2016.0
# 1              2  Spooky's Jump Scare Mansion  2016.0
# 2              3  Spooky's Jump Scare Mansion  2016.0
# 3              4  Spooky's Jump Scare Mansion  2015.0
# 4              5  Spooky's Jump Scare Mansion  2015.0
# ...          ...                          ...     ...
# 17489      25535                 EverQuest II  2012.0
# 17490      25536                 EverQuest II  2017.0
# 17491      25537                 EverQuest II  2011.0
# 17492      25538                 EverQuest II     NaN
# 17493      25539                 EverQuest II     NaN
#
# ...

# %%
# integrate tokization funtionality, add stop word removal for preprocessing, lemmariztion, chunking, steming

# %%
import pickle
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np

nltk.download('punkt')
print("------------------------------------------------------------")
nltk.download('wordnet')

wordnet_lemmatizer = WordNetLemmatizer()

nrows = len(data)
lemmatized_text_list = []

for i in range(0, nrows):
    
    lemmatized_list = []
    
    text = data.loc[i]['Content_Parsed_4']
    text_words = text.split(" ")

    for word in text_words:
        lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))
        
    lemmatized_text = " ".join(lemmatized_list)
    
    lemmatized_text_list.append(lemmatized_text)

    

data['Content_Parsed_5'] = lemmatized_text_list

# %%
#stopwords

regex = r"\b" + word + r"\b"

data['Content_Parsed_6'] = data['Content_Parsed_5']

for stop_word in stop_words:

    regex_stopword = r"\b" + stop_word + r"\b"
    data['Content_Parsed_6'] = data['Content_Parsed_6'].str.replace(regex_stopword, '')

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer() 

stemmed = []

for i in processed:
    stem = stemmer.stem(i)  
    stemmed.append(stem)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

lemmatized = []

for i in processed:
    lemma = lemmatizer.lemmatize(i)
    lemmatized.append(lemma)

# %%
import spacy
spacy.info('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")
doc_df = processed['Content_Parsed_6'].apply(nlp)

# %%
from textblob import TextBlob
blob_df = processed['Content_Parsed_6'].apply(TextBlob)
